# %% [markdown]
# # Walkthrough cookbook smolagents
#
# [https://huggingface.co/learn/cookbook/agent_data_analyst](https://huggingface.co/learn/cookbook/agent_data_analyst)

# %%
# !pip install matplotlib numpy pandas

# %%
# !pip install seaborn smolagents transformers -q -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 14.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 83.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 MB 25.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.4/321.4 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 81.4 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 59.8 MB/s eta 0:00:00:00:01
# ...

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
from smolagents import HfApiModel, CodeAgent
import os

model = HfApiModel("Qwen/Qwen2.5-Coder-32B-Instruct")

agent = CodeAgent(
    tools=[],
    model=model,
    additional_authorized_imports=["numpy", "pandas", "matplotlib.pyplot", "seaborn"],
    #max_iterations=10,
)

# %%
import os

os.mkdir("./figures")

# %%
additional_notes = """
### Variable Notes
pclass: A proxy for socio-economic status (SES)
1st = Upper
2nd = Middle
3rd = Lower
age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
sibsp: The dataset defines family relations in this way...
Sibling = brother, sister, stepbrother, stepsister
Spouse = husband, wife (mistresses and fiancés were ignored)
parch: The dataset defines family relations in this way...
Parent = mother, father
Child = daughter, son, stepdaughter, stepson
Some children travelled only with a nanny, therefore parch=0 for them.
"""

analysis = agent.run(
    """You are an expert data analyst.
Please load the source file and analyze its content.
According to the variables you have, begin by listing 3 interesting questions that could be asked on this data, for instance about specific correlations with survival rate.
Then answer these questions one by one, by finding the relevant numbers.
Meanwhile, plot some figures using matplotlib/seaborn and save them to the (already existing) folder './figures/': take care to clear each figure with plt.clf() before doing another plot.

In your final answer: summarize these correlations and trends
After each number derive real worlds insights, for instance: "Correlation between is_december and boredness is 1.3453, which suggest people are more bored in winter".
Your final answer should have at least 3 numbered and detailed parts.
""",
    additional_args=dict(additional_notes=additional_notes, source_file="/kaggle/input/titanic/train.csv"),
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ You are an expert data analyst.                                                                                 │
# │ Please load the source file and analyze its content.                                                            │
# │ According to the variables you have, begin by listing 3 interesting questions that could be asked on this data, │
# │ for instance about specific correlations with survival rate.                                                    │
# │ Then answer these questions one by one, by finding the relevant numbers.                                        │
# │ Meanwhile, plot some figures using matplotlib/seaborn and save them to the (already existing) folder            │
# ...

# %% [markdown]
# # Error can't debug
#
# No module named '_gdbm', please install the python3-gdbm package
#
# no idea how to fix

# %%
print(analysis)
# Out:
# {'summary': {'1': 'There is a clear positive correlation between socio-economic status and survival rate. Passengers in the upper class (1st class) had a significantly higher survival rate compared to those in the lower classes (3rd class).', '2': 'The age distribution of passengers was relatively young, with the majority of passengers being between 20 and 38 years old. This suggests that the Titanic had a mix of young adults and children, but fewer elderly passengers.', '3': 'Passengers with 1 sibling or spouse had the highest survival rate (53.59%). This could suggest that having a family member on board might have provided some advantage in terms of survival. However, the survival rate for passengers with more than 1 sibling/spouse was not significantly higher, and it even decreased for those with 3 or more siblings/spouses, which might indicate resource constraints or difficulties in managing larger families during the evacuation.'}}

# %%
# !pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py) ...   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install scikit-learn

# %%
agent2 = CodeAgent(
    tools=[],
    model=model,
    additional_authorized_imports=[
        "numpy",
        "pandas",
        "matplotlib.pyplot",
        "seaborn",
        "sklearn",
    ],
    #max_iterations=12,
)

output = agent2.run(
    """You are an expert machine learning engineer.
Please train a ML model on "/kaggle/input/titanic/train.csv" to predict the survival for rows of "/kaggle/input/titanic/test.csv".
Output the results under '/kaggle/working/output.csv'.
Take care to import functions and modules before using them!
""",
    additional_args=dict(additional_notes=additional_notes),
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ You are an expert machine learning engineer.                                                                    │
# │ Please train a ML model on "/kaggle/input/titanic/train.csv" to predict the survival for rows of                │
# │ "/kaggle/input/titanic/test.csv".                                                                               │
# │ Output the results under '/kaggle/working/output.csv'.                                                          │
# │ Take care to import functions and modules before using them!                                                    │
# │                                                                                                                 │
# ...

# %% [markdown]
# # Good performance
#
# Validation Accuracy: 0.8212290502793296
#
# would get top 10% on Kaggle I think
#
# - checked that it did indeed save Output.csv to working directory also
